# %%
#引入约定
import pandas as pd

# %%
from pandas import Series, DataFrame

# %% [markdown]
# Series 可以被视为一个带标签的一维数组。它结合了 NumPy 数组的高效性（快速的矢量化操作）和 Python 字典的灵活索引

# %%
obj = pd.Series([4,7,-5,3])

# %%
obj #表现形式是索引在左边，值在右边
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  7, -5,  3])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
#可以自己定义索引
obj2 = pd.Series([4,7,-5,3], index=['d','b','a','c'])

# %%
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2['a']
# Out:
# np.int64(-5)

# %%
#可以通过字典来创建Series:
sdata = {'Ohio':35000,'Texas':71000,'Oregon':16000,'Utah':5000}

# %%
obj3 = pd.Series(sdata)

# %%
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
#可以利用自己创建的序列来检测缺少数据
states = ['California','Ohio','Oregon','Texas']

# %%
obj4 = pd.Series(sdata,index=states)

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
#检测缺失数据
obj4.isnull()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
#Series对象本身以及索引带有一个name属性

# %%
obj4.name = 'population'

# %%
obj4.index.name = 'state'

# %%
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %% [markdown]
# 索引可以通过赋值修改

# %% [markdown]
# DataFreame是一个表格型的数据结构，Pandas 中的 DataFrame 是最重要、最核心的数据结构，可以将其视为一个带标签的二维表格。
#
# 简单来说，DataFrame 就是一张功能强大的电子表格或数据库中的表。

# %%
#建DataFrame的办法有很多，最常用的是一种直接传入一个由等长列表或者Numpy数组组成的字典
data = {'state':['Ohio','Ohio','Ohio','Nevada','Nevada','Nevada'],'year':[2000,2001,2002,2001,2002,2003],'pop':[1.5,1.7,3.6,2.4,2.9,3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
#对于特别大的DataFrame,head方法会选取前五行：frame.head()

# %%
#可以指定列的排列顺序
pd.DataFrame(data,columns=['year','state','pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data,columns=['year','state','pop','debt'],index=['one','two','three','four','five','six'])

# %%
frame2
# Out:
#        year   state  pop debt
# one    2000    Ohio  1.5  NaN
# two    2001    Ohio  1.7  NaN
# three  2002    Ohio  3.6  NaN
# four   2001  Nevada  2.4  NaN
# five   2002  Nevada  2.9  NaN
# six    2003  Nevada  3.2  NaN

# %%
#可以将DataFrame的列获取为一个Series:
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
#列可以通过赋值修改
frame2['debt'] = 16.5

# %%
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5  16.5
# two    2001    Ohio  1.7  16.5
# three  2002    Ohio  3.6  16.5
# four   2001  Nevada  2.4  16.5
# five   2002  Nevada  2.9  16.5
# six    2003  Nevada  3.2  16.5

# %%
val = pd.Series([-1.2,-1.5,-1.7])
